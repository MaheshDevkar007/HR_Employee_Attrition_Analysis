# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Netizens\OneDrive\Desktop\Employee_Salary_Analysis\Dataset\WA_Fn-UseC_-HR-Employee-Attrition.csv")

df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Dataset Information
df. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# Dataset Statistics
df. describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
# Employee Attrition Count
df["Attrition"].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
import numpy as np

# Average Age
print("Average Age:", np.mean(df["Age"]))
# Out:
# Average Age: 36.923809523809524

# %%
# Average Monthly Income
print("Average Monthly Income:", np.mean(df["MonthlyIncome"]))

# Maximum Monthly Income
print("Highest Monthly Income:", np.max(df["MonthlyIncome"]))

# Minimum Monthly Income
print("Lowest Monthly Income:", np.min(df["MonthlyIncome"]))
# Out:
# Average Monthly Income: 6502.931292517007
# Highest Monthly Income: 19999
# Lowest Monthly Income: 1009

# %%
# Department-wise Employee Count
df ["Department"] . value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
df.groupby("Department")["MonthlyIncome"].mean()
# Out:
# Department
# Human Resources           6654.507937
# Research & Development    6281.252862
# Sales                     6959.172646
# Name: MonthlyIncome, dtype: float64

# %%
df . groupby(["Department" , "Attrition"]).size()
# Out:
# Department              Attrition
# Human Resources         No            51
#                         Yes           12
# Research & Development  No           828
#                         Yes          133
# Sales                   No           354
#                         Yes           92
# dtype: int64

# %%
# check Missing Values
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#check Duplicate Records
df.duplicated().sum()
# Out:
# 0

# %%
#Average Age
print("Average Age:",
      np.mean(df["Age"]))
# Out:
# Average Age: 36.923809523809524

# %%
# Gender Count
df["Gender"].value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
# job Role count
df["JobRole"].value_counts()
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %%
# Education wise  Employee Count
df["Education"].value_counts()
# Out:
# Education
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: count, dtype: int64

# %%
#Maretial Status
df["MaritalStatus"].value_counts()
# Out:
# MaritalStatus
# Married     673
# Single      470
# Divorced    327
# Name: count, dtype: int64

# %%
#Overtime Count
df["OverTime"].value_counts()
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64

# %%
#Average Total Working Years 
print (np.mean(df["TotalWorkingYears"]))
# Out:
# 11.279591836734694

# %%
#job Satisfaction Average
print(np.mean(df["JobSatisfaction"]))
# Out:
# 2.7285714285714286

# %%
# avrage monthly income
avg_income = np.mean(df["MonthlyIncome"])

if avg_income > 5000:
    print("Average salary is above 5000")
else:
    print("Average salary is below 5000")
# Out:
# Average salary is above 5000

# %%
def average_salary():
    avg = np.mean(df["MonthlyIncome"])
    return avg

print("Average Salary:", average_salary())
# Out:
# Average Salary: 6502.931292517007

# %%
# loop concept
departments = df["Department"].unique()

for dept in departments:
    print(dept)
# Out:
# Sales
# Research & Development
# Human Resources

# %%
try:
    df = pd.read_csv(r"C:\Users\Netizens\OneDrive\Desktop\Employee_Salary_Analysis\Dataset\WA_Fn-UseC_-HR-Employee-Attrition.csv")
    print("Dataset Loaded Successfully")
except FileNotFoundError:
    print("File Not Found")
# Out:
# Dataset Loaded Successfully

# %% [markdown]
# # Business Insights
#
# - Total Employees: 1470
# - Employees Left Company: 237
# - Attrition Rate: Around 16%
# - Research & Development has the highest number of employees.
# - Average Monthly Income: Around 6503.
# - No missing values found in the dataset.
# - Department-wise salary analysis completed.
